# %% [markdown]
# 1. Download the dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0ed2cf1c-7d76-4d4a-a1b6-e9f57d6ed54c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ed2cf1c-7d76-4d4a-a1b6-e9f57d6ed54c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Basic imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# 2. Load the dataset

# %%
import pandas as pd
data=pd.read_csv('abalone.csv')

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
data.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %% [markdown]
# Univariate Analysis

# %%
sns.distplot(data.Length) # univariate analysis
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Height)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["Whole weight"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["Shucked weight"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["Viscera weight"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["Shell weight"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Rings)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Bivariate Analysis

# %%
sns.lineplot(data.Length,data.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data.Height,data.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data.Height,data.Rings)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data.Length,data.Rings)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data.Rings,data.Diameter)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data["Shell weight"],data.Rings)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Multi-Variate Analysis

# %%
sns.pairplot(data=data,aspect=.85);

# %%
data.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# 4.Perform descriptive statistics on the dataset

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# 5. Check for Missing values and deal with them

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# 6. Find the outliers and replace them outliers

# %%
sns.boxplot(data.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Q1= data.Length.quantile(0.25)
Q3=data.Length.quantile(0.75)

# %%
IQR=Q3-Q1

# %%
upper_limit =Q3 + 1.5*IQR
lower_limit =Q1 - 1.5*IQR

# %%
upper_limit
# Out:
# 0.8624999999999999

# %%
lower_limit
# Out:
# 0.20250000000000004

# %%
data=data[data.Length>lower_limit]
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
sns.boxplot(data.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7. Check for Categorical columns and perform encoding

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data.Gender = le.fit_transform(data.Sex)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# 8. Split the data into dependent and independent variables

# %%
# independent variable-X
X=data.drop(columns=['Rings'],axis=1)
X.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight
# 0         0.150
# 1         0.070
# 2         0.210
# 3         0.155
# 4         0.055

# %%
# y target-dependent variable
y=data.Rings
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4128, dtype: int64

# %% [markdown]
#  9. Scale the independent
# variables

# %%
from sklearn.preprocessing import scale

# %%
X=data.drop(columns=['Sex'],axis=1)
X.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
X_scaled=pd.DataFrame(scale(X),columns=X.columns)
X_scaled.head()
# Out:
#      Length  Diameter    Height  Whole weight  Shucked weight  Viscera weight  \
# 0 -0.640050 -0.486733 -1.124397     -0.667786       -0.631719       -0.751783
# 1 -1.558230 -1.540370 -1.247472     -1.262092       -1.199926       -1.235204
# 2  0.015792  0.092768 -0.139801     -0.332009       -0.486258       -0.378858
# 3 -0.771219 -0.486733 -0.385950     -0.663666       -0.672630       -0.632078
# 4 -1.733122 -1.645734 -1.493621     -1.304321       -1.245382       -1.318077
#
#    Shell weight     Rings
# 0     -0.664565  1.573391
# 1     -1.245362 -0.946110
# 2     -0.228968 -0.316234
# 3     -0.628266 -0.001297
# 4     -1.354261 -0.946110

# %% [markdown]
# 10. Split the data into training and testing

# %%
X.shape
# Out:
# (4128, 8)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X_scaled,y, test_size=0.3,random_state=0)

# %%
X_train
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 3297  0.496744  0.672268  1.090945      0.039818       -0.077149
# 3127  0.671635  0.830314  0.352498      0.648543        0.634245
# 3442 -0.202822  0.672268  0.475572      0.571294        0.661519
# 1245 -0.508882 -0.486733 -1.001323     -0.879965       -0.856729
# 349   1.895875  1.831269  1.829393      3.421281        2.559329
# ...        ...       ...       ...           ...             ...
# 1033  2.070766  1.989314  1.952468      3.015464        2.925254
# 3264  0.627912  0.356177  0.844796      0.450785        0.088767
# 1653  0.802804  0.777632  0.967871      0.650603        0.591061
# 2607 -0.333990 -0.381369 -0.385950     -0.604957       -0.383981
# 2732  0.365575  0.356177  0.352498      0.368385        0.741068
#
#       Viscera weight  Shell weight     Rings
# 3297       -0.038160      0.242929  0.628578
# 3127        0.624818      0.388128  1.573391
# 3442        0.518925      0.471617 -0.631172
# ...

# %%
X_train.shape
# Out:
# (2889, 8)

# %%
y_train.shape
# Out:
# (2889,)

# %%
X_test
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 1065 -0.683773 -0.750142 -0.509024     -0.712076       -0.556716
# 45   -1.208448 -1.224279 -1.124397     -1.308441       -1.254473
# 1569 -0.027931 -0.117960 -0.016726     -0.379389       -0.265794
# 1280  0.059515  0.250813  0.229423     -0.249610       -0.072604
# 3249 -0.159099 -0.170642 -0.509024     -0.454578       -0.461257
# ...        ...       ...       ...           ...             ...
# 874  -2.520133 -2.488643 -2.108994     -1.581389       -1.538577
# 2115 -0.989833 -0.908188 -0.632099     -1.014894       -1.013554
# 1739 -2.214073 -2.488643 -1.247472     -1.249732       -1.215835
# 1362  0.890249  0.777632  0.106349      0.461084        0.650155
# 1239 -0.640050 -0.486733 -0.632099     -0.839795       -0.815818
#
#       Viscera weight  Shell weight     Rings
# 1065       -0.691931     -0.882364 -1.261047
# 45         -1.267433     -1.209062 -0.946110
# 1569       -0.208509     -0.526626 -0.946110
# ...

# %%
X_test.shape
# Out:
# (1239, 8)

# %%
y_test.shape
# Out:
# (1239,)

# %% [markdown]
# 11. Build the Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %% [markdown]
# 12. Train the Model

# %%
train_pred = model.predict(X_train)
train_pred
# Out:
# array([11, 13,  9, ..., 11,  8, 10])

# %% [markdown]
# 13. Test the Model

# %%
test_pred= model.predict(X_test)
test_pred
# Out:
# array([ 7,  7,  8, ...,  6, 11,  8])

# %%
y_test
# Out:
# 1088     6
# 45       7
# 1594     7
# 1304     9
# 3290    12
#         ..
# 893      5
# 2145     9
# 1764     5
# 1386    12
# 1263     8
# Name: Rings, Length: 1239, dtype: int64

# %% [markdown]
# 14. Measure the performance using Metrics

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
ridge = Ridge()
lasso = Lasso()

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
y_train_pred = ridge.predict(X_train)
y_train_pred
# Out:
# array([11.99999573, 14.99715479,  8.00211598, ..., 11.99956419,
#         8.00002982,  9.99924861])

# %%
y_test_pred = ridge.predict(X_test)
y_test_pred
# Out:
# array([ 6.00132094,  7.00052952,  7.0012823 , ...,  5.00090543,
#        11.99920626,  8.00054282])

# %%
y_train_predl = lasso.predict(X_train)
y_train_pred
# Out:
# array([11.99999573, 14.99715479,  8.00211598, ..., 11.99956419,
#         8.00002982,  9.99924861])

# %%
y_test_predl = lasso.predict(X_test)
y_test_predl
# Out:
# array([ 7.24499795,  7.93171522,  7.93171522, ...,  6.55828069,
#        11.36530154,  8.61843248])

# %%
from sklearn import metrics

# %%
# MSE
# ridge mse
metrics.mean_squared_error(y_test,y_test_pred)
# Out:
# 2.469251378526869e-06

# %%
# lasso mse
metrics.mean_squared_error(y_test,y_test_predl)
# Out:
# 0.9776277024367009

# %%
# RMSE
#ridge rmse
np.sqrt(metrics.mean_squared_error(y_test,y_test_pred))
# Out:
# 0.0015713851782828006

# %%
# lasso rmse 
np.sqrt(metrics.mean_squared_error(y_test,y_test_predl))
# Out:
# 0.9887505764532838

# %% [markdown]
# R2 Score

# %%
# ridge training accuracy

metrics.r2_score(y_train,y_train_pred)
# Out:
# 0.9999997583152526

# %%
# testing accuracy of ridge

metrics.r2_score(y_test,y_test_pred)
# Out:
# 0.9999997518565495

# %%
# lasso training  accuracy

metrics.r2_score(y_train,y_train_predl)
# Out:
# 0.9018539274623049

# %%
# testing accuracy of lasso

metrics.r2_score(y_test,y_test_predl)
# Out:
# 0.901754874612962
